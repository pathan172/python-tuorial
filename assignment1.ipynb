# %%
# 1 write a python program that print 
#python is fun.
#"quotes"and 'single quote' can be tricky 
print("python is fun.")
print('''"quotes"and 'single quote' can be tricky ''')
# Out:
# python is fun.
# "quotes"and 'single quote' can be tricky

# %%
#2..for a business create 3 variables to store name,age,and city.then print a statement thaat uses these variavles
name ="anzar"
age = 21
city = "bihar"
print(f"my name is {name} from {city} and i'm {age}")
# Out:
# my name is anzar from bihar and i'm 21
