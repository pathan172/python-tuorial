# %%
a= input ("enter your name:")
print(a)
# Out:
# enter your name: md anzar khan
# md anzar khan

# %%
name = input("enter your name:")
print(f"welcome {name} to the python tutorial series")
# Out:
# enter your name: kallu kaliya
# welcome kallu kaliya to the python tutorial series

# %%
age = input("enter your age:")
print(f"so next year you will be the {int(age)+1} !")
# Out:
# enter your age: 23
# so next year you will be the 24 !

# %%
x= input("enter first number:")
y = input("enter second number:")
print(f"sum of {x} & {y} is {int(x) + int(y)} ")
# Out:
# enter first number: 23
# enter second number: 32
# sum of 23 & 32 is 55
