# %%
print("hello world")
# Out:
# hello world

# %%
#python as a calculator
print(5+3)
b= 10
c=20
print(b+c)
print(c/b)
print(c*b)
# Out:
# 8
# 30
# 2.0
# 200

# %%
instructor="anzar khan"
print("python by",instructor)
# Out:
# python by anzar khan
