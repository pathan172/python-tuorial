# %%
#if_else
#take a input of age and on the basis of age print eligible or not eligilble fro driving license

age= int(input())
if(age>=18): 
    print("eligibl for driving license")
   
else:
    print("not eligible")
# Out:
#  54
# eligibl for driving license

# %%
age = int(input())
if (age>=18):
    test= input()
    if test=="PASS":
        print("eligible fro driving licencse")
    else:
        print("not eligible for driving licesne")
else:
    print("not eligible")
# Out:
#  20
#  PASS
# eligible fro driving licencse

# %%
marks=int(input())
if marks>=90:
    print("excellent")
elif marks>=70:
    print("good")
elif marks>=40:
    print("fair")
else:
    print("bad")
# Out:
#  95
# excellent

# %%
temp = int (input())
if temp<=50 and temp>=25:
    print("hot")
elif temp<=25 and temp>=10:
    print("cold")
else:
    print("extreme cold")
# Out:
#  2
# extreme cold

# %%
#ternary operator
age = int(input())
result ="eligible"if age>=18 else"not eligible"
print(result)
# Out:
#  12
# not eligible
