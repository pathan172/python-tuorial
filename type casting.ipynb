# %%
a=1
print(type(a))
b='1'
print(type(b))
c=int(b)
print(a+c)
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# 2
# <class 'int'>

# %%
mynum = 26
mynum2 =str(mynum)
print(type(mynum2))
# Out:
# <class 'str'>

# %%
#implicit casting
var1 = 20
var2 = 15.5
var3 = var1+var2
print(var3)
print(type(var3))
# Out:
# 35.5
# <class 'float'>

# %%
#explicit function is the opposite of implicit function
