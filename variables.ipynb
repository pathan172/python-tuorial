# %%
a=1
print(a)
# Out:
# 1

# %%
b=1.3756
print(b)
# Out:
# 1.3756

# %%
c="Anzar"
print(c)
# Out:
# Anzar

# %%
x=10
print(x+1)
# Out:
# 11

# %%
#ways to declare a variables
#MyName="anzar"....pascal case
#myName="anzar"....camel case
#myname="anzar"....flat case
#MyName="anzar"....pascal case

# %%
a=1
b=2
print(a+b)
print(type(a))
# Out:
# 3
# <class 'int'>

# %%
c="1"
d="2"
print(c+d)
print(type(c))
# Out:
# 12
# <class 'str'>

# %%
d="anzar"
print(type(d))
# Out:
# <class 'str'>

# %%
d2=[1,2,3,4,'anzar']
print(type(d2))
# Out:
# <class 'list'>

# %%
d3={1,2,3,4,'anzar'}
print(type(d3))
# Out:
# <class 'set'>

# %%
my_dict = {'name':"anzar",'age':21,'city':"bihar"}
print(my_dict)
print(type(my_dict))
# Out:
# {'name': 'anzar', 'age': 21, 'city': 'bihar'}
# <class 'dict'>
